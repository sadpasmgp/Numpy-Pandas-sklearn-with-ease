# %% [markdown]
# #### Pandas Built-in Data Visualization | ML

# %%
import numpy as np 
import pandas as pd 
  
# There are some fake data csv files 
# you can read in as dataframes 
df1 = pd.read_csv('df1.csv', index_col = 0) 
df2 = pd.read_csv('df2.csv')

# %% [markdown]
# #### Style Sheets –
#
# Matplotlib has style sheets which can be used to make the plots look a little nicer. These style sheets include plot_bmh, plot_fivethirtyeight, plot_ggplot and more

# %%
import matplotlib.pyplot as plt

df1['A'].hist() 

plt.style.use('ggplot')

# %%
plt.style.use('bmh') 
df1['A'].hist()

# %%
plt.style.use('dark_background') 
df1['A'].hist()

# %%
plt.style.use('fivethirtyeight') 
df1['A'].hist()

# %% [markdown]
# #### Plot Types –
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
#     df.plot.area
#     df.plot.barh
#     df.plot.density
#     df.plot.hist
#     df.plot.line
#     df.plot.scatter
#     df.plot.bar
#     df.plot.box
#     df.plot.hexbin
#     df.plot.kde
#     df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. ‘box’, ‘barh’, etc.)

# %% [markdown]
# #### 1.) Area
#
# An area chart or area graph displays graphically quantitative data. It is based on the line chart. The area between axis and line are commonly emphasized with colors, textures and hatchings. Commonly one compares two or more quantities with an area chart.

# %%
plt.style.use('ggplot')
df2.plot.area(alpha = 0.4)

# %% [markdown]
# #### 2.) Barplots
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a line graph

# %%
df2.plot.bar() 
plt.style.use('ggplot')

# %%
df2.plot.bar(stacked = True)

# %% [markdown]
# #### 3.) Histograms
#
# A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc.

# %%
df1['A'].plot.hist(bins = 50)

# %% [markdown]
# #### 4. Line Plots
#
# A line plot is a graph that shows frequency of data along a number line. It is best to use a line plot when the data is time series. It is a quick, simple way to organize data.

# %%
df1.plot.line( y ='B', figsize =(12, 3), lw = 1)

# %% [markdown]
# ##### 5.) Scatter Plots
#
# Scatter plots are used when you want to show the relationship between two variables. Scatter plots are sometimes called correlation plots because they show how two variables are correlated.

# %%
df1.plot.scatter(x ='A', y ='B')

# %%
df1.plot.scatter(x ='A', y ='B', c ='C', cmap ='coolwarm')

# %% [markdown]
# You can use c to color based off another column value Use cmap to indicate colormap to use

# %% [markdown]
# Or use s to indicate size based off another column. s parameter needs to be an array, not just the name of a column:

# %%
df1.plot.scatter(x ='A', y ='B', s = df1['C']*200)
# Out:
# C:\Users\sadiqgpasha\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### 6.) Box Plots
#
# It is a plot in which a rectangle is drawn to represent the second and third quartiles, usually with a vertical line inside to indicate the median value. The lower and upper quartiles are shown as horizontal lines either side of the rectangle.
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.

# %%
df2.plot.box() # Can also pass a by = argument for groupby

# %% [markdown]
# #### 7.) Hexagonal Bin Plots
#
# Hexagonal Binning is another way to manage the problem of having to many points that start to overlap. Hexagonal binning plots density, rather than points. Points are binned into gridded hexagons and distribution (the number of points per hexagon) is displayed using either the color or the area of the hexagons.
# Useful for Bivariate Data, alternative to scatterplot:

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns =['a', 'b']) 
df.plot.hexbin(x ='a', y ='b', gridsize = 25, cmap ='Oranges')

# %% [markdown]
# ##### 8.) Kernel Density Estimation plot (KDE)
#
# KDE is a technique that let’s you create a smooth curve given a set of data.
#
# This can be useful if you want to visualize just the “shape” of some data, as a kind of continuous replacement for the discrete histogram. It can also be used to generate points that look like they came from a certain dataset – this behavior can power simple simulations, where simulated objects are modeled off of real data.

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %% [markdown]
# #### Data analysis and Visualization with Python

# %%
# Import the pandas library, renamed as pd 
import pandas as pd 
  
# Read IND_data.csv into a DataFrame, assigned to df 
df = pd.read_csv("CountryData.IND.csv") 
  
# Prints the first 5 rows of a DataFrame as default 
print(df.head()) 
  
# Prints no. of rows and columns of a DataFrame 
df.shape
# Out:
#    Series Code Frequency          Series Units of measurement  \
# 0  IT_USE_ii99    Annual  Internet users   Per 100 population
# 1  IT_USE_ii99    Annual  Internet users   Per 100 population
# 2  IT_USE_ii99    Annual  Internet users   Per 100 population
# 3  SE_ADT_1524    Annual   Literacy rate              Percent
# 4  SE_ADT_1524    Annual   Literacy rate              Percent
#
#                  Location        Age group         Sex Reference Area  \
# 0  Total (national level)   All age ranges  Both sexes          India
# 1  Total (national level)   All age ranges  Both sexes          India
# 2  Total (national level)   All age ranges  Both sexes          India
# 3  Total (national level)  15-24 year olds  Both sexes          India
# 4  Total (national level)  15-24 year olds  Both sexes          India
#
#      Source type  Time period  Observation Value Unit multiplier  \
# 0  Not available         1999                0.2           Units
# 1  Not available         2002                3.2           Units
# 2  Not available         2006                7.0           Units
# 3  Not available         1991               48.5           Units
# 4  Not available         2001               76.4           Units
#
#   Nature of data points  Time period details  \
# 0          Country Data                 1999
# 1          Country Data                 2002
# 2          Country Data                 2006
# 3          Country Data                 1991
# 4          Country Data                 2001
#
#                        Source details  Footnotes
# 0  Ministry of Information Technology        NaN
# 1  Ministry of Information Technology        NaN
# 2  Ministry of Information Technology        NaN
# 3                 Planning Commission        NaN
# 4                 Planning Commission        NaN
# (29, 16)

# %% [markdown]
# Indexing can be possible using the pandas.DataFrame.iloc method. The iloc method allows to retrieve as  many as rows and columns by position.

# %%
# prints first 5 rows and every column which replicates df.head() 
df.iloc[0:5,:]
# Out:
#    Series Code Frequency          Series Units of measurement  \
# 0  IT_USE_ii99    Annual  Internet users   Per 100 population
# 1  IT_USE_ii99    Annual  Internet users   Per 100 population
# 2  IT_USE_ii99    Annual  Internet users   Per 100 population
# 3  SE_ADT_1524    Annual   Literacy rate              Percent
# 4  SE_ADT_1524    Annual   Literacy rate              Percent
#
#                  Location        Age group         Sex Reference Area  \
# 0  Total (national level)   All age ranges  Both sexes          India
# 1  Total (national level)   All age ranges  Both sexes          India
# 2  Total (national level)   All age ranges  Both sexes          India
# 3  Total (national level)  15-24 year olds  Both sexes          India
# 4  Total (national level)  15-24 year olds  Both sexes          India
#
#      Source type  Time period  Observation Value Unit multiplier  \
# 0  Not available         1999                0.2           Units
# 1  Not available         2002                3.2           Units
# 2  Not available         2006                7.0           Units
# 3  Not available         1991               48.5           Units
# 4  Not available         2001               76.4           Units
#
#   Nature of data points  Time period details  \
# 0          Country Data                 1999
# 1          Country Data                 2002
# 2          Country Data                 2006
# 3          Country Data                 1991
# 4          Country Data                 2001
#
#                        Source details  Footnotes
# 0  Ministry of Information Technology        NaN
# 1  Ministry of Information Technology        NaN
# 2  Ministry of Information Technology        NaN
# 3                 Planning Commission        NaN
# 4                 Planning Commission        NaN

# %%
# prints entire rows and columns 
df.iloc[:,:]
# Out:
#     Series Code Frequency                                             Series  \
# 0   IT_USE_ii99    Annual                                     Internet users
# 1   IT_USE_ii99    Annual                                     Internet users
# 2   IT_USE_ii99    Annual                                     Internet users
# 3   SE_ADT_1524    Annual                                      Literacy rate
# 4   SE_ADT_1524    Annual                                      Literacy rate
# 5   SH_DYN_MORT    Annual                          Under-five mortality rate
# 6   SH_DYN_MORT    Annual                          Under-five mortality rate
# 7   SH_DYN_MORT    Annual                          Under-five mortality rate
# 8   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 9   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 10  SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 11  SH_STA_MORT    Annual                           Maternal mortality ratio
# 12  SH_STA_MORT    Annual                           Maternal mortality ratio
# 13  SH_STA_MORT    Annual                           Maternal mortality ratio
# 14  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 15  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 16  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 17  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 18  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 19  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 20  SI_POV_NAHC    Annual             Population below national poverty line
# 21  SI_POV_NAHC    Annual             Population below national poverty line
# 22  SI_POV_NAHC    Annual             Population below national poverty line
# 23  SI_POV_NAHC    Annual             Population below national poverty line
# 24  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 25  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 26  SN_STA_MALN    Annual        Children moderately or severely underweight
# 27  SN_STA_MALN    Annual        Children moderately or severely underweight
# 28  SN_STA_MALN    Annual        Children moderately or severely underweight
#
#        Units of measurement                Location          Age group  \
# 0        Per 100 population  Total (national level)     All age ranges
# 1        Per 100 population  Total (national level)     All age ranges
# 2        Per 100 population  Total (national level)     All age ranges
# 3                   Percent  Total (national level)    15-24 year olds
# 4                   Percent  Total (national level)    15-24 year olds
# 5     Per 1,000 live births  Total (national level)  under 5 year olds
# 6     Per 1,000 live births  Total (national level)  under 5 year olds
# 7     Per 1,000 live births  Total (national level)  under 5 year olds
# 8                   Percent  Total (national level)     Not applicable
# 9                   Percent  Total (national level)     Not applicable
# 10                  Percent  Total (national level)     Not applicable
# 11  Per 100,000 live births  Total (national level)     All age ranges
# 12  Per 100,000 live births  Total (national level)     All age ranges
# 13  Per 100,000 live births  Total (national level)     All age ranges
# 14   Per 100,000 population  Total (national level)     All age ranges
# 15   Per 100,000 population  Total (national level)     All age ranges
# 16   Per 100,000 population  Total (national level)     All age ranges
# 17   Per 100,000 population  Total (national level)     All age ranges
# 18   Per 100,000 population  Total (national level)     All age ranges
# 19   Per 100,000 population  Total (national level)     All age ranges
# 20                  Percent  Total (national level)     All age ranges
# 21                  Percent  Total (national level)     All age ranges
# 22                  Percent  Total (national level)     All age ranges
# 23                  Percent  Total (national level)     All age ranges
# 24                  Percent  Total (national level)     All age ranges
# 25                  Percent  Total (national level)     All age ranges
# 26                  Percent  Total (national level)  under 5 year olds
# 27                  Percent  Total (national level)  under 5 year olds
# 28                  Percent  Total (national level)  under 5 year olds
#
#                Sex Reference Area    Source type  Time period  \
# 0       Both sexes          India  Not available         1999
# 1       Both sexes          India  Not available         2002
# 2       Both sexes          India  Not available         2006
# 3       Both sexes          India  Not available         1991
# 4       Both sexes          India  Not available         2001
# 5       Both sexes          India  Not available         1992
# 6       Both sexes          India  Not available         1998
# 7       Both sexes          India  Not available         2005
# 8   Not applicable          India  Not available         1992
# 9   Not applicable          India  Not available         1998
# 10  Not applicable          India  Not available         2005
# 11          Female          India  Not available         1997
# 12          Female          India  Not available         2000
# 13          Female          India  Not available         2002
# 14      Both sexes          India  Not available         1990
# 15      Both sexes          India  Not available         2000
# 16      Both sexes          India  Not available         2001
# 17      Both sexes          India  Not available         2002
# 18      Both sexes          India  Not available         2003
# 19      Both sexes          India  Not available         2004
# 20      Both sexes          India  Not available         1993
# 21      Both sexes          India  Not available         1999
# 22      Both sexes          India  Not available         2004
# 23      Both sexes          India  Not available         2005
# 24          Female          India  Not available         1999
# 25          Female          India  Not available         2004
# 26      Both sexes          India  Not available         1992
# 27      Both sexes          India  Not available         1998
# 28      Both sexes          India  Not available         2005
#
#     Observation Value Unit multiplier Nature of data points  \
# 0                 0.2           Units          Country Data
# 1                 3.2           Units          Country Data
# 2                 7.0           Units          Country Data
# 3                48.5           Units          Country Data
# 4                76.4           Units          Country Data
# 5               109.3           Units          Country Data
# 6                94.9           Units          Country Data
# 7                74.3           Units          Country Data
# 8                33.0           Units          Country Data
# 9                42.4           Units          Country Data
# 10               48.2           Units          Country Data
# 11              398.0           Units          Country Data
# 12              327.0           Units          Country Data
# 13              301.0           Units          Country Data
# 14              503.0           Units          Country Data
# 15              412.0           Units          Country Data
# 16              371.0           Units          Country Data
# 17              343.0           Units          Country Data
# 18              287.0           Units          Country Data
# 19              312.0           Units          Country Data
# 20               36.0           Units          Country Data
# 21               26.1           Units          Country Data
# 22               27.5           Units          Country Data
# 23               21.8           Units          Country Data
# 24               16.0           Units          Country Data
# 25               20.2           Units          Country Data
# 26               51.5           Units          Country Data
# 27               47.0           Units          Country Data
# 28               45.9           Units          Country Data
#
#     Time period details                       Source details  Footnotes
# 0                  1999   Ministry of Information Technology        NaN
# 1                  2002   Ministry of Information Technology        NaN
# 2                  2006   Ministry of Information Technology        NaN
# 3                  1991                  Planning Commission        NaN
# 4                  2001                  Planning Commission        NaN
# 5                  1992        National Family Health Survey        NaN
# 6                  1998        National Family Health Survey        NaN
# 7                  2005        National Family Health Survey        NaN
# 8                  1992        National Family Health Survey        NaN
# 9                  1998        National Family Health Survey        NaN
# 10                 2005        National Family Health Survey        NaN
# 11                 1997           Sample Registration System        NaN
# 12                 2000           Sample Registration System        NaN
# 13                 2002           Sample Registration System        NaN
# 14                 1990                                  NaN        NaN
# 15                 2000                                  NaN        NaN
# 16                 2001                                  NaN        NaN
# 17                 2002                                  NaN        NaN
# 18                 2003                                  NaN        NaN
# 19                 2004                                  NaN        NaN
# 20                 1993                  Planning Commission        NaN
# 21                 1999                  Planning Commission        NaN
# 22                 2004                  Planning Commission        NaN
# 23                 2005                  Planning Commission        NaN
# 24                 1999  National Sample Survey Organization        NaN
# 25                 2004  National Sample Survey Organization        NaN
# 26                 1992        National Family Health Survey        NaN
# 27                 1998        National Family Health Survey        NaN
# 28                 2005        National Family Health Survey        NaN

# %%
# prints from 5th rows and first 5 columns 
df.iloc[5:,:5]
# Out:
#     Series Code Frequency                                             Series  \
# 5   SH_DYN_MORT    Annual                          Under-five mortality rate
# 6   SH_DYN_MORT    Annual                          Under-five mortality rate
# 7   SH_DYN_MORT    Annual                          Under-five mortality rate
# 8   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 9   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 10  SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 11  SH_STA_MORT    Annual                           Maternal mortality ratio
# 12  SH_STA_MORT    Annual                           Maternal mortality ratio
# 13  SH_STA_MORT    Annual                           Maternal mortality ratio
# 14  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 15  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 16  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 17  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 18  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 19  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 20  SI_POV_NAHC    Annual             Population below national poverty line
# 21  SI_POV_NAHC    Annual             Population below national poverty line
# 22  SI_POV_NAHC    Annual             Population below national poverty line
# 23  SI_POV_NAHC    Annual             Population below national poverty line
# 24  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 25  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 26  SN_STA_MALN    Annual        Children moderately or severely underweight
# 27  SN_STA_MALN    Annual        Children moderately or severely underweight
# 28  SN_STA_MALN    Annual        Children moderately or severely underweight
#
#        Units of measurement                Location
# 5     Per 1,000 live births  Total (national level)
# 6     Per 1,000 live births  Total (national level)
# 7     Per 1,000 live births  Total (national level)
# 8                   Percent  Total (national level)
# 9                   Percent  Total (national level)
# 10                  Percent  Total (national level)
# 11  Per 100,000 live births  Total (national level)
# 12  Per 100,000 live births  Total (national level)
# 13  Per 100,000 live births  Total (national level)
# 14   Per 100,000 population  Total (national level)
# 15   Per 100,000 population  Total (national level)
# 16   Per 100,000 population  Total (national level)
# 17   Per 100,000 population  Total (national level)
# 18   Per 100,000 population  Total (national level)
# 19   Per 100,000 population  Total (national level)
# 20                  Percent  Total (national level)
# 21                  Percent  Total (national level)
# 22                  Percent  Total (national level)
# 23                  Percent  Total (national level)
# 24                  Percent  Total (national level)
# 25                  Percent  Total (national level)
# 26                  Percent  Total (national level)
# 27                  Percent  Total (national level)
# 28                  Percent  Total (national level)

# %% [markdown]
# Indexing can be worked with labels using the pandas.DataFrame.loc method, which allows to index using labels instead of positions.

# %%
# Prints the first 5 rows of Time period 
# value  
df.loc[:5,"Time period"]
# Out:
# 0    1999
# 1    2002
# 2    2006
# 3    1991
# 4    2001
# 5    1992
# Name: Time period, dtype: int64

# %% [markdown]
# Computation of data frames can be done by using Statistical Functions of pandas tools.

# %%
# computes various summary statistics, excluding NaN values 
df.describe()
# Out:
#        Time period  Observation Value  Time period details  Footnotes
# count    29.000000          29.000000            29.000000        0.0
# mean   1999.551724         140.806897          1999.551724        NaN
# std       4.807629         156.922569             4.807629        NaN
# min    1990.000000           0.200000          1990.000000        NaN
# 25%    1998.000000          27.500000          1998.000000        NaN
# 50%    2000.000000          48.500000          2000.000000        NaN
# 75%    2004.000000         301.000000          2004.000000        NaN
# max    2006.000000         503.000000          2006.000000        NaN

# %%
# for computing correlations 
df.corr()
# Out:
#                      Time period  Observation Value  Time period details  \
# Time period             1.000000          -0.095092             1.000000
# Observation Value      -0.095092           1.000000            -0.095092
# Time period details     1.000000          -0.095092             1.000000
# Footnotes                    NaN                NaN                  NaN
#
#                      Footnotes
# Time period                NaN
# Observation Value          NaN
# Time period details        NaN
# Footnotes                  NaN

# %%
# computes numerical data ranks 
df.rank()
# Out:
#     Series Code  Frequency  Series  Units of measurement  Location  Age group  \
# 0           2.0       15.0     8.0                   5.0      15.0       11.5
# 1           2.0       15.0     8.0                   5.0      15.0       11.5
# 2           2.0       15.0     8.0                   5.0      15.0       11.5
# 3           4.5       15.0    10.5                  22.5      15.0        1.5
# 4           4.5       15.0    10.5                  22.5      15.0        1.5
# 5           7.0       15.0    28.0                   2.0      15.0       26.5
# 6           7.0       15.0    28.0                   2.0      15.0       26.5
# 7           7.0       15.0    28.0                   2.0      15.0       26.5
# 8          10.0       15.0     2.0                  22.5      15.0       22.0
# 9          10.0       15.0     2.0                  22.5      15.0       22.0
# 10         10.0       15.0     2.0                  22.5      15.0       22.0
# 11         13.0       15.0    13.0                   8.0      15.0       11.5
# 12         13.0       15.0    13.0                   8.0      15.0       11.5
# 13         13.0       15.0    13.0                   8.0      15.0       11.5
# 14         17.5       15.0    23.5                  12.5      15.0       11.5
# 15         17.5       15.0    23.5                  12.5      15.0       11.5
# 16         17.5       15.0    23.5                  12.5      15.0       11.5
# 17         17.5       15.0    23.5                  12.5      15.0       11.5
# 18         17.5       15.0    23.5                  12.5      15.0       11.5
# 19         17.5       15.0    23.5                  12.5      15.0       11.5
# 20         22.5       15.0    16.5                  22.5      15.0       11.5
# 21         22.5       15.0    16.5                  22.5      15.0       11.5
# 22         22.5       15.0    16.5                  22.5      15.0       11.5
# 23         22.5       15.0    16.5                  22.5      15.0       11.5
# 24         25.5       15.0    19.5                  22.5      15.0       11.5
# 25         25.5       15.0    19.5                  22.5      15.0       11.5
# 26         28.0       15.0     5.0                  22.5      15.0       26.5
# 27         28.0       15.0     5.0                  22.5      15.0       26.5
# 28         28.0       15.0     5.0                  22.5      15.0       26.5
#
#      Sex  Reference Area  Source type  Time period  Observation Value  \
# 0   11.0            15.0         15.0         12.0                1.0
# 1   11.0            15.0         15.0         19.0                2.0
# 2   11.0            15.0         15.0         29.0                3.0
# 3   11.0            15.0         15.0          2.0               15.0
# 4   11.0            15.0         15.0         16.5               18.0
# 5   11.0            15.0         15.0          4.0               20.0
# 6   11.0            15.0         15.0          9.0               19.0
# 7   11.0            15.0         15.0         26.5               17.0
# 8   28.0            15.0         15.0          4.0                9.0
# 9   28.0            15.0         15.0          9.0               11.0
# 10  28.0            15.0         15.0         26.5               14.0
# 11  24.0            15.0         15.0          7.0               27.0
# 12  24.0            15.0         15.0         14.5               24.0
# 13  24.0            15.0         15.0         19.0               22.0
# 14  11.0            15.0         15.0          1.0               29.0
# 15  11.0            15.0         15.0         14.5               28.0
# 16  11.0            15.0         15.0         16.5               26.0
# 17  11.0            15.0         15.0         19.0               25.0
# 18  11.0            15.0         15.0         21.0               21.0
# 19  11.0            15.0         15.0         23.0               23.0
# 20  11.0            15.0         15.0          6.0               10.0
# 21  11.0            15.0         15.0         12.0                7.0
# 22  11.0            15.0         15.0         23.0                8.0
# 23  11.0            15.0         15.0         26.5                6.0
# 24  24.0            15.0         15.0         12.0                4.0
# 25  24.0            15.0         15.0         23.0                5.0
# 26  11.0            15.0         15.0          4.0               16.0
# 27  11.0            15.0         15.0          9.0               13.0
# 28  11.0            15.0         15.0         26.5               12.0
#
#     Unit multiplier  Nature of data points  Time period details  \
# 0              15.0                   15.0                 12.0
# 1              15.0                   15.0                 19.0
# 2              15.0                   15.0                 29.0
# 3              15.0                   15.0                  2.0
# 4              15.0                   15.0                 16.5
# 5              15.0                   15.0                  4.0
# 6              15.0                   15.0                  9.0
# 7              15.0                   15.0                 26.5
# 8              15.0                   15.0                  4.0
# 9              15.0                   15.0                  9.0
# 10             15.0                   15.0                 26.5
# 11             15.0                   15.0                  7.0
# 12             15.0                   15.0                 14.5
# 13             15.0                   15.0                 19.0
# 14             15.0                   15.0                  1.0
# 15             15.0                   15.0                 14.5
# 16             15.0                   15.0                 16.5
# 17             15.0                   15.0                 19.0
# 18             15.0                   15.0                 21.0
# 19             15.0                   15.0                 23.0
# 20             15.0                   15.0                  6.0
# 21             15.0                   15.0                 12.0
# 22             15.0                   15.0                 23.0
# 23             15.0                   15.0                 26.5
# 24             15.0                   15.0                 12.0
# 25             15.0                   15.0                 23.0
# 26             15.0                   15.0                  4.0
# 27             15.0                   15.0                  9.0
# 28             15.0                   15.0                 26.5
#
#     Source details  Footnotes
# 0              2.0        NaN
# 1              2.0        NaN
# 2              2.0        NaN
# 3             17.5        NaN
# 4             17.5        NaN
# 5              8.0        NaN
# 6              8.0        NaN
# 7              8.0        NaN
# 8              8.0        NaN
# 9              8.0        NaN
# 10             8.0        NaN
# 11            22.0        NaN
# 12            22.0        NaN
# 13            22.0        NaN
# 14             NaN        NaN
# 15             NaN        NaN
# 16             NaN        NaN
# 17             NaN        NaN
# 18             NaN        NaN
# 19             NaN        NaN
# 20            17.5        NaN
# 21            17.5        NaN
# 22            17.5        NaN
# 23            17.5        NaN
# 24            13.5        NaN
# 25            13.5        NaN
# 26             8.0        NaN
# 27             8.0        NaN
# 28             8.0        NaN

# %% [markdown]
# Plots in these examples are made using standard convention for referencing the matplotlib API which provides the basics in pandas to easily create decent looking plots.

# %%
# import the required module  
import matplotlib.pyplot as plt 
# plot a histogram  
df['Observation Value'].hist(bins=10)

# %%
# shows presence of a lot of outliers/extreme values 
df.boxplot(column='Observation Value', by = 'Time period')

# %%
# plotting points as a scatter plot 
x = df["Observation Value"] 
y = df["Time period"] 
plt.scatter(x, y, label= "stars", color= "m",  
            marker= "*", s=30) 
# x-axis label 
plt.xlabel('Observation Value') 
# frequency label 
plt.ylabel('Time period') 
# function to show the plot 
plt.show()

# %% [markdown]
# #### Box plot visualization with Pandas and Seaborn

# %% [markdown]
# Box Plot is the visual representation of the depicting groups of numerical data through their quartiles. Boxplot is also used for detect the outlier in data set. It captures the summary of the data efficiently with a simple box and whiskers and allows us to compare easily across groups. Boxplot summarizes a sample data using 25th, 50th and 75th percentiles. These percentiles are also known as the lower quartile, median and upper quartile.

# %% [markdown]
# A box plot consist of 5 things.
#
#     Minimum
#     First Quartile or 25%
#     Median (Second Quartile) or 50%
#     Third Quartile or 75%
#     Maximum

# %% [markdown]
# One way to plot boxplot using pandas dataframe is to use boxplot() function that is part of pandas library.

# %%
# import the required library  
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline 
  
#load the dataset 
df = pd.read_csv("tips.csv") 
  
# display 5 rows of dataset 
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Boxplot of days with respect total_bill.

# %%
df.boxplot(by ='day', column =['total_bill'], grid = False)

# %% [markdown]
# Boxplot of size with respect tip.

# %%
df.boxplot(by ='size', column =['tip'], grid = False)

# %% [markdown]
# Draw the boxplot using seaborn library:
#
#     Syntax :
#     seaborn.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)
#
#     Parameters:
#     x = feature of dataset
#     y = feature of dataset
#     hue = feature of dataset
#     data = datafram or full dataset
#     color = color name

# %% [markdown]
# Let’s see how to create the box plot through seaborn library.
#
# Information about “tips” dataset.

# %%
import seaborn as sns

# load the dataset 
tips = sns.load_dataset('tips') 
  
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Boxplot of days with respect total_bill.

# %%
# Draw a vertical boxplot grouped  
# by a categorical variable: 
sns.set_style("whitegrid") 
  
sns.boxplot(x = 'day', y = 'total_bill', data = tips)

# %% [markdown]
# Let’s take the first box plot i.e, orange box plot of the figure and understand these statistical things:
#
#     Bottom black horizontal line of blue box plot is minimum value
#     First black horizontal line of rectangle shape of blue box plot is First quartile or 25%
#     Second black horizontal line of rectangle shape of blue box plot is Second quartile or 50% or median.
#     Third black horizontal line of rectangle shape of blue box plot is third quartile or 75%
#     Top black horizontal line of rectangle shape of orange box plot is maximum value.
#     Small diamond shape of blue box plot is outlier data or erroneous data.
