# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %% [markdown]
# On the website, copy the data and pandas will read the data from clipboard

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#     Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0       1           Dallas Cowboys     898    512    380      6  0.573
# 1       2            Chicago Bears   1,386    761    583     42  0.564
# 2       3        Green Bay Packers   1,352    743    571     38  0.564
# 3       4  New England Patriots[b]     900    500    391      9  0.561
# 4       5           Miami Dolphins     816    452    360      4  0.556
# 5       6        Minnesota Vikings     886    478    397     11  0.546
# 6       7         Baltimore Ravens     368    200    167      1  0.545
# 7       8          New York Giants   1,321    692    596     33  0.536
# 8       9           Denver Broncos     900    476    414     10  0.534
# 9      10      San Francisco 49ers   1,018    532    472     14  0.529
# 10     11    Indianapolis Colts[c]     982    516    459      7  0.529
# 11     12      Pittsburgh Steelers   1,208    628    558     22  0.529
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank ', 'Team ', 'GP ', 'Won ', 'Lost ', 'Tied ', 'Pct. ',
#        'First NFL Season ', 'Division'],
#       dtype='object')

# %%
nfl_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 9 columns):
# Rank                 32 non-null int64
# Team                 32 non-null object
# GP                   32 non-null object
# Won                  32 non-null int64
# Lost                 32 non-null int64
# Tied                 32 non-null int64
# Pct.                 32 non-null float64
# First NFL Season     32 non-null int64
# Division             32 non-null object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 2.3+ KB

# %%
nfl_frame.head()
# Out:
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      1           Dallas Cowboys     898    512    380      6  0.573
# 1      2            Chicago Bears   1,386    761    583     42  0.564
# 2      3        Green Bay Packers   1,352    743    571     38  0.564
# 3      4  New England Patriots[b]     900    500    391      9  0.561
# 4      5           Miami Dolphins     816    452    360      4  0.556
#
#    First NFL Season    Division
# 0               1960   NFC East
# 1               1920  NFC North
# 2               1921  NFC North
# 3               1960   AFC East
# 4               1966   AFC East

# %%
nfl_frame.Division.unique()
# Out:
# array(['NFC East', 'NFC North', 'AFC East', 'AFC North', 'AFC West',
#        'NFC West', 'AFC South', 'NFC South'], dtype=object)

# %% [markdown]
# Notice the space after each column name, strip that extra space

# %%
nfl_frame.columns = [x.strip() for x in nfl_frame.columns]

# %% [markdown]
# Now to access multiple columns, pass columns as list

# %%
nfl_frame[["Rank", "Team","GP"]].head(10)
# Out:
#    Rank                      Team      GP
# 0     1           Dallas Cowboys     898
# 1     2            Chicago Bears   1,386
# 2     3        Green Bay Packers   1,352
# 3     4  New England Patriots[b]     900
# 4     5           Miami Dolphins     816
# 5     6        Minnesota Vikings     886
# 6     7         Baltimore Ravens     368
# 7     8          New York Giants   1,321
# 8     9           Denver Broncos     900
# 9    10      San Francisco 49ers   1,018

# %% [markdown]
# Retrieve rows of a dataframe

# %%
nfl_frame.loc[3]
# Out:
# Rank                                       4
# Team                New England Patriots[b]
# GP                                      900
# Won                                      500
# Lost                                     391
# Tied                                       9
# Pct.                                   0.561
# First NFL Season                        1960
# Division                            AFC East
# Name: 3, dtype: object

# %%
nfl_frame.iloc[4]
# Out:
# Rank                              5
# Team                Miami Dolphins
# GP                             816
# Won                             452
# Lost                            360
# Tied                              4
# Pct.                          0.556
# First NFL Season               1966
# Division                   AFC East
# Name: 4, dtype: object

# %% [markdown]
# Accessing multiple rows

# %%
nfl_frame.loc[3:7]
# Out:
#    Rank                      Team      GP  Won  Lost  Tied   Pct.  \
# 3     4  New England Patriots[b]     900   500   391     9  0.561
# 4     5           Miami Dolphins     816   452   360     4  0.556
# 5     6        Minnesota Vikings     886   478   397    11  0.546
# 6     7         Baltimore Ravens     368   200   167     1  0.545
# 7     8          New York Giants   1,321   692   596    33  0.536
#
#    First NFL Season   Division
# 3              1960   AFC East
# 4              1966   AFC East
# 5              1961  NFC North
# 6              1996  AFC North
# 7              1925   NFC East

# %% [markdown]
# choosing rows and columns simultaneously

# %%
nfl_frame.loc[5:20]['Team']
# Out:
# 5           Minnesota Vikings
# 6            Baltimore Ravens
# 7             New York Giants
# 8              Denver Broncos
# 9         San Francisco 49ers
# 10      Indianapolis Colts[c]
# 11        Pittsburgh Steelers
# 12         Kansas City Chiefs
# 13            Oakland Raiders
# 14           Seattle Seahawks
# 15        Washington Redskins
# 16    Los Angeles Chargers[d]
# 17           Los Angeles Rams
# 18          Carolina Panthers
# 19        Philadelphia Eagles
# 20           Cleveland Browns
# Name: Team, dtype: object

# %%
nfl_frame.loc[5:20][["Team","Won","Tied"]]
# Out:
#                         Team  Won  Tied
# 5         Minnesota Vikings   478    11
# 6          Baltimore Ravens   200     1
# 7           New York Giants   692    33
# 8            Denver Broncos   476    10
# 9       San Francisco 49ers   532    14
# 10    Indianapolis Colts[c]   516     7
# 11      Pittsburgh Steelers   628    22
# 12       Kansas City Chiefs   469    12
# 13          Oakland Raiders   466    11
# 14         Seattle Seahawks   344     1
# 15      Washington Redskins   600    28
# 16  Los Angeles Chargers[d]   447    11
# 17         Los Angeles Rams   568    21
# 18        Carolina Panthers   190     1
# 19      Philadelphia Eagles   577    26
# 20         Cleveland Browns   469    11

# %% [markdown]
# Accessing with a condition

# %%
nfl_frame.loc[(nfl_frame.Won>500) & (nfl_frame.Tied>10)]
# Out:
#     Rank                  Team      GP  Won  Lost  Tied   Pct.  \
# 1      2        Chicago Bears   1,386   761   583    42  0.564
# 2      3    Green Bay Packers   1,352   743   571    38  0.564
# 7      8      New York Giants   1,321   692   596    33  0.536
# 9     10  San Francisco 49ers   1,018   532   472    14  0.529
# 11    12  Pittsburgh Steelers   1,208   628   558    22  0.529
# 15    16  Washington Redskins   1,218   600   590    28  0.504
# 17    18     Los Angeles Rams   1,151   568   562    21  0.503
# 19    20  Philadelphia Eagles   1,204   577   601    26  0.490
# 23    24        Detroit Lions   1,249   559   658    32  0.460
# 30    31    Arizona Cardinals   1,346   553   753    40  0.426
#
#     First NFL Season   Division
# 1               1920  NFC North
# 2               1921  NFC North
# 7               1925   NFC East
# 9               1950   NFC West
# 11              1933  AFC North
# 15              1932   NFC East
# 17              1937   NFC West
# ...
